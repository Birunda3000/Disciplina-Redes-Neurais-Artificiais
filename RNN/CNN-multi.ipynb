# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, mean_squared_error
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

from tensorflow.keras.callbacks import EarlyStopping

import json
import os
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
from IPython.display import display

drive.mount('/content/drive')
diretorio = '/content/drive/MyDrive/Redes Neurais/DATA/'
diretorio2 = '/content/drive/MyDrive/Redes Neurais/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_t = np.load(diretorio+'X_train.npy')
y_t = np.load(diretorio+'y_train.npy')

X_v = np.load(diretorio+'X_test.npy')
y_v = np.load(diretorio+'y_test.npy')

X_t.shape, y_t.shape
# Out:
# ((8640, 100, 52), (8640, 52))

# %%
model = Sequential()

model.add(InputLayer((100, 52)))
model.add(Conv1D(filters=1000, kernel_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=10, kernel_size=2))
model.add(Flatten())
model.add(Dense(1024, 'relu'))
model.add(Dense(128, 'sigmoid'))
model.add(Dense(52, 'linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 99, 1000)          105000
#
#  max_pooling1d (MaxPooling1D  (None, 49, 1000)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 48, 10)            20010
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 1024)              492544
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  dense_2 (Dense)             (None, 52)                6708
#
# =================================================================
# Total params: 755,462
# Trainable params: 755,462
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
EPOCHS = 100
batch_size = 64
patience = 20 #no improvement patience

# %%
model.compile(optimizer='adam', loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

earlystopper = EarlyStopping(monitor='loss', patience=patience, restore_best_weights=True, verbose=0)

history = model.fit(X_t, y_t, batch_size=batch_size, epochs=EPOCHS, callbacks=[earlystopper], validation_data=(X_v, y_v))
# Out:
# Epoch 1/100
# 135/135 [==============================] - 9s 21ms/step - loss: 0.0207 - root_mean_squared_error: 0.1437 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 2/100
# 135/135 [==============================] - 3s 19ms/step - loss: 0.0022 - root_mean_squared_error: 0.0474 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0744
# Epoch 3/100
# 135/135 [==============================] - 2s 12ms/step - loss: 0.0012 - root_mean_squared_error: 0.0341 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0714
# Epoch 4/100
# 135/135 [==============================] - 2s 16ms/step - loss: 8.5022e-04 - root_mean_squared_error: 0.0292 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0708
# Epoch 5/100
# 135/135 [==============================] - 2s 13ms/step - loss: 6.5813e-04 - root_mean_squared_error: 0.0257 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0695
# Epoch 6/100
# 135/135 [==============================] - 2s 12ms/step - loss: 5.6461e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 7/100
# 135/135 [==============================] - 1s 9ms/step - loss: 4.2177e-04 - root_mean_squared_error: 0.0205 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0644
# Epoch 8/100
# 135/135 [==============================] - 1s 9ms/step - loss: 3.9441e-04 - root_mean_squared_error: 0.0199 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 9/100
# 135/135 [==============================] - 1s 9ms/step - loss: 3.2852e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 10/100
# 135/135 [==============================] - 2s 12ms/step - loss: 2.9537e-04 - root_mean_squared_error: 0.0172 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0648
# Epoch 11/100
# 135/135 [==============================] - 1s 9ms/step - loss: 3.1290e-04 - root_mean_squared_error: 0.0177 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0614
# Epoch 12/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.7078e-04 - root_mean_squared_error: 0.0165 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 13/100
# 135/135 [==============================] - 1s 8ms/step - loss: 2.6566e-04 - root_mean_squared_error: 0.0163 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 14/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.4308e-04 - root_mean_squared_error: 0.0156 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0608
# Epoch 15/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.7250e-04 - root_mean_squared_error: 0.0165 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0592
# Epoch 16/100
# 135/135 [==============================] - 1s 8ms/step - loss: 2.0079e-04 - root_mean_squared_error: 0.0142 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0588
# Epoch 17/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.0182e-04 - root_mean_squared_error: 0.0142 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0594
# Epoch 18/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.6160e-04 - root_mean_squared_error: 0.0162 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0601
# Epoch 19/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.0986e-04 - root_mean_squared_error: 0.0145 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0587
# Epoch 20/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.7949e-04 - root_mean_squared_error: 0.0134 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 21/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8243e-04 - root_mean_squared_error: 0.0135 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0569
# Epoch 22/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.9934e-04 - root_mean_squared_error: 0.0141 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 23/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8965e-04 - root_mean_squared_error: 0.0138 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0575
# Epoch 24/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5826e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0554
# Epoch 25/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8135e-04 - root_mean_squared_error: 0.0135 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 26/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5757e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0572
# Epoch 27/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.0469e-04 - root_mean_squared_error: 0.0143 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0577
# Epoch 28/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.6577e-04 - root_mean_squared_error: 0.0129 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0579
# Epoch 29/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.7704e-04 - root_mean_squared_error: 0.0133 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0570
# Epoch 30/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5920e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0579
# Epoch 31/100
# 135/135 [==============================] - 2s 11ms/step - loss: 1.5967e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0580
# Epoch 32/100
# 135/135 [==============================] - 2s 12ms/step - loss: 2.4673e-04 - root_mean_squared_error: 0.0157 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0604
# Epoch 33/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3975e-04 - root_mean_squared_error: 0.0118 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0578
# Epoch 34/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5927e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0606
# Epoch 35/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3996e-04 - root_mean_squared_error: 0.0118 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0585
# Epoch 36/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2484e-04 - root_mean_squared_error: 0.0112 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0582
# Epoch 37/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8150e-04 - root_mean_squared_error: 0.0135 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0595
# Epoch 38/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2661e-04 - root_mean_squared_error: 0.0113 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 39/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3177e-04 - root_mean_squared_error: 0.0115 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 40/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3703e-04 - root_mean_squared_error: 0.0117 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 41/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.4042e-04 - root_mean_squared_error: 0.0119 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0605
# Epoch 42/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5627e-04 - root_mean_squared_error: 0.0125 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 43/100
# 135/135 [==============================] - 1s 10ms/step - loss: 2.0444e-04 - root_mean_squared_error: 0.0143 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0619
# Epoch 44/100
# 135/135 [==============================] - 1s 10ms/step - loss: 1.4018e-04 - root_mean_squared_error: 0.0118 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 45/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2687e-04 - root_mean_squared_error: 0.0113 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 46/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1683e-04 - root_mean_squared_error: 0.0108 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0633
# Epoch 47/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.7138e-04 - root_mean_squared_error: 0.0131 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0631
# Epoch 48/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2549e-04 - root_mean_squared_error: 0.0112 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 49/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1207e-04 - root_mean_squared_error: 0.0106 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 50/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3569e-04 - root_mean_squared_error: 0.0116 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0620
# Epoch 51/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.7140e-04 - root_mean_squared_error: 0.0131 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0625
# Epoch 52/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2457e-04 - root_mean_squared_error: 0.0112 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 53/100
# 135/135 [==============================] - 1s 10ms/step - loss: 1.1351e-04 - root_mean_squared_error: 0.0107 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0646
# Epoch 54/100
# 135/135 [==============================] - 2s 12ms/step - loss: 1.4373e-04 - root_mean_squared_error: 0.0120 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0694
# Epoch 55/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.4604e-04 - root_mean_squared_error: 0.0157 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0638
# Epoch 56/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0081e-04 - root_mean_squared_error: 0.0100 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0617
# Epoch 57/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.1799e-05 - root_mean_squared_error: 0.0096 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 58/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1008e-04 - root_mean_squared_error: 0.0105 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 59/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3376e-04 - root_mean_squared_error: 0.0116 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0657
# Epoch 60/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0401e-04 - root_mean_squared_error: 0.0102 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 61/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.0298e-05 - root_mean_squared_error: 0.0095 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 62/100
# 135/135 [==============================] - 1s 8ms/step - loss: 9.4417e-05 - root_mean_squared_error: 0.0097 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0658
# Epoch 63/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2451e-04 - root_mean_squared_error: 0.0112 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0677
# Epoch 64/100
# 135/135 [==============================] - 2s 12ms/step - loss: 1.1300e-04 - root_mean_squared_error: 0.0106 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 65/100
# 135/135 [==============================] - 1s 10ms/step - loss: 1.0624e-04 - root_mean_squared_error: 0.0103 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0636
# Epoch 66/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.1173e-05 - root_mean_squared_error: 0.0095 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0665
# Epoch 67/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1568
# Epoch 68/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0182 - root_mean_squared_error: 0.1348 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290
# Epoch 69/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0449 - root_mean_squared_error: 0.2118 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2056
# Epoch 70/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2091
# Epoch 71/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2063
# Epoch 72/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0513 - root_mean_squared_error: 0.2265 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2063
# Epoch 73/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2076
# Epoch 74/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0417 - val_root_mean_squared_error: 0.2042
# Epoch 75/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262 - val_loss: 0.0423 - val_root_mean_squared_error: 0.2057
# Epoch 76/100
# 135/135 [==============================] - 2s 12ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0425 - val_root_mean_squared_error: 0.2061
# Epoch 77/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0511 - root_mean_squared_error: 0.2262 - val_loss: 0.0441 - val_root_mean_squared_error: 0.2099
# Epoch 78/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262 - val_loss: 0.0427 - val_root_mean_squared_error: 0.2067
# Epoch 79/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0512 - root_mean_squared_error: 0.2262 - val_loss: 0.0432 - val_root_mean_squared_error: 0.2079
# Epoch 80/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0513 - root_mean_squared_error: 0.2264 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2075
# Epoch 81/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0511 - root_mean_squared_error: 0.2260 - val_loss: 0.0435 - val_root_mean_squared_error: 0.2085

# %%
predictions = model.predict(X_v)
predictions.shape
# Out:
# 180/180 [==============================] - 1s 2ms/step
# (5760, 52)

# %%
path_to_save = '/content/drive/MyDrive/Redes Neurais/results/CNN/multi/sensor_'
try:
    os.remove(path_to_save)
except FileNotFoundError:
    pass

final_result = {}
final_result['Model'] = 'CNN-multi'

for i in range(len(predictions[0])):
  final_result['Sensor'] = i
  final_result['Model'] = 'CNN-multi'
  final_result['MSE_val_final'] = mean_squared_error(y_v[:,i], predictions[:,i]).numpy().tolist()

  with open(path_to_save+".json", "a") as arquivo:
    json.dump(final_result, arquivo)

# %%
plt.plot(history.history['root_mean_squared_error'], label='RME')
plt.plot(history.history['val_root_mean_squared_error'], label = 'val_RME')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss/RME')
plt.legend(loc='lower right')
plt.savefig(path_to_save+'_loss.png')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
predictions = model.predict(X_v)

predictions.shape
# Out:
# 180/180 [==============================] - 0s 2ms/step
# (5760, 52)

# %%
r = random.randint(0,51)
plt.plot(predictions[:,r])
plt.plot(y_v[:,r])

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_prediction(original_data, predicted_data):
    """
    Plots the original time series, predicted time series, difference between them, and the absolute difference.
    Returns:
        None (displays the plot)
    """

    # Convert data to numpy arrays if they are DataFrames
    if isinstance(original_data, pd.DataFrame):
        original_data = original_data.values
    if isinstance(predicted_data, pd.DataFrame):
        predicted_data = predicted_data.values

    # Compute the difference between the original and predicted data
    diff = original_data - predicted_data
    abs_diff = np.abs(diff)  # Compute the absolute difference

    # Get the number of time series
    num_series = original_data.shape[1]

    # Create subplots for the plots of each time series
    fig, axes = plt.subplots(nrows=num_series, ncols=1, figsize=(10, 5*num_series))
    plt.tight_layout(pad=1.0)

    # Iterate over each time series
    for i in range(num_series):
        ax = axes[i]

        # Plot the original data
        ax.plot(original_data[:, i], label='Original')

        # Plot the predicted data
        ax.plot(predicted_data[:, i], label='Predicted')

        # Plot the difference between original and predicted data
        ax.plot(diff[:, i], label='Difference')

        # Plot the absolute difference
        ax.plot(abs_diff[:, i], label='Absolute Difference')

        # Set the title and legend for each subplot
        ax.set_title(f'Time Series {i+1}')
        ax.legend()
        plt.savefig('/content/drive/MyDrive/Redes Neurais/results/CNN/multi/sensor_'+str(i)+'_diff.png')
        print('.',end='')

    # Display the plot

    plt.show()

# %%
plot_prediction(y_v, predictions)

# %%
from datetime import datetime
import pytz

# Get the current time in Brazil's time zone
brazil_tz = pytz.timezone('America/Sao_Paulo')
current_time = datetime.now(brazil_tz)

# Print the current time
print(current_time)
# Out:
# 2023-06-24 19:06:34.381314-03:00
