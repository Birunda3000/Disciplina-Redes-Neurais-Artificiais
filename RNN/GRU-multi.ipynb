# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, mean_squared_error
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

from tensorflow.keras.callbacks import EarlyStopping

import json
import os
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
from IPython.display import display

drive.mount('/content/drive')
diretorio = '/content/drive/MyDrive/Redes Neurais/DATA/'
diretorio2 = '/content/drive/MyDrive/Redes Neurais/'
# Out:
# Mounted at /content/drive

# %%
X_t = np.load(diretorio+'X_train.npy')
y_t = np.load(diretorio+'y_train.npy')

X_v = np.load(diretorio+'X_test.npy')
y_v = np.load(diretorio+'y_test.npy')

X_t.shape, y_t.shape
# Out:
# ((8640, 100, 52), (8640, 52))

# %%
model = Sequential()

model.add(InputLayer((100, 52)))
model.add(GRU(100))
model.add(Dense(128, 'sigmoid'))
model.add(Dense(52, 'linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 100)               46200
#
#  dense (Dense)               (None, 128)               12928
#
#  dense_1 (Dense)             (None, 52)                6708
#
# =================================================================
# Total params: 65,836
# Trainable params: 65,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
EPOCHS = 100
batch_size = 64
patience = 20 #no improvement patience

# %%
model.compile(optimizer='adam', loss=MeanSquaredError(), metrics=[RootMeanSquaredError()])

earlystopper = EarlyStopping(monitor='loss', patience=patience, restore_best_weights=True, verbose=0)

history = model.fit(X_t, y_t, batch_size=batch_size, epochs=EPOCHS, callbacks=[earlystopper], validation_data=(X_v, y_v))
# Out:
# Epoch 1/100
# 135/135 [==============================] - 9s 15ms/step - loss: 0.0374 - root_mean_squared_error: 0.1934 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 2/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0707
# Epoch 3/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0017 - root_mean_squared_error: 0.0408 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 4/100
# 135/135 [==============================] - 1s 9ms/step - loss: 0.0012 - root_mean_squared_error: 0.0352 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0596
# Epoch 5/100
# 135/135 [==============================] - 2s 11ms/step - loss: 9.5119e-04 - root_mean_squared_error: 0.0308 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0574
# Epoch 6/100
# 135/135 [==============================] - 2s 14ms/step - loss: 7.2745e-04 - root_mean_squared_error: 0.0270 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0521
# Epoch 7/100
# 135/135 [==============================] - 2s 12ms/step - loss: 5.6521e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 8/100
# 135/135 [==============================] - 1s 9ms/step - loss: 4.6997e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0484
# Epoch 9/100
# 135/135 [==============================] - 1s 9ms/step - loss: 4.1159e-04 - root_mean_squared_error: 0.0203 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0452
# Epoch 10/100
# 135/135 [==============================] - 1s 9ms/step - loss: 3.6474e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0445
# Epoch 11/100
# 135/135 [==============================] - 1s 9ms/step - loss: 3.2610e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0431
# Epoch 12/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.9474e-04 - root_mean_squared_error: 0.0172 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 13/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.6792e-04 - root_mean_squared_error: 0.0164 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 14/100
# 135/135 [==============================] - 1s 8ms/step - loss: 2.4917e-04 - root_mean_squared_error: 0.0158 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0394
# Epoch 15/100
# 135/135 [==============================] - 1s 9ms/step - loss: 2.3242e-04 - root_mean_squared_error: 0.0152 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 16/100
# 135/135 [==============================] - 2s 12ms/step - loss: 2.1886e-04 - root_mean_squared_error: 0.0148 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0381
# Epoch 17/100
# 135/135 [==============================] - 1s 11ms/step - loss: 2.0731e-04 - root_mean_squared_error: 0.0144 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0383
# Epoch 18/100
# 135/135 [==============================] - 1s 11ms/step - loss: 1.9631e-04 - root_mean_squared_error: 0.0140 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 19/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8757e-04 - root_mean_squared_error: 0.0137 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0365
# Epoch 20/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.8098e-04 - root_mean_squared_error: 0.0135 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0366
# Epoch 21/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.7004e-04 - root_mean_squared_error: 0.0130 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 22/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.6784e-04 - root_mean_squared_error: 0.0130 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0363
# Epoch 23/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.6325e-04 - root_mean_squared_error: 0.0128 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 24/100
# 135/135 [==============================] - 1s 8ms/step - loss: 1.5930e-04 - root_mean_squared_error: 0.0126 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358
# Epoch 25/100
# 135/135 [==============================] - 1s 8ms/step - loss: 1.5301e-04 - root_mean_squared_error: 0.0124 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0361
# Epoch 26/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.5038e-04 - root_mean_squared_error: 0.0123 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0348
# Epoch 27/100
# 135/135 [==============================] - 2s 12ms/step - loss: 1.4439e-04 - root_mean_squared_error: 0.0120 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 28/100
# 135/135 [==============================] - 2s 13ms/step - loss: 1.4010e-04 - root_mean_squared_error: 0.0118 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 29/100
# 135/135 [==============================] - 1s 10ms/step - loss: 1.3706e-04 - root_mean_squared_error: 0.0117 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357
# Epoch 30/100
# 135/135 [==============================] - 1s 8ms/step - loss: 1.3707e-04 - root_mean_squared_error: 0.0117 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# Epoch 31/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3425e-04 - root_mean_squared_error: 0.0116 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 32/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.3129e-04 - root_mean_squared_error: 0.0115 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 33/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2672e-04 - root_mean_squared_error: 0.0113 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 34/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2759e-04 - root_mean_squared_error: 0.0113 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 35/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2272e-04 - root_mean_squared_error: 0.0111 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# Epoch 36/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.2288e-04 - root_mean_squared_error: 0.0111 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 37/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1886e-04 - root_mean_squared_error: 0.0109 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 38/100
# 135/135 [==============================] - 1s 11ms/step - loss: 1.1964e-04 - root_mean_squared_error: 0.0109 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 39/100
# 135/135 [==============================] - 2s 12ms/step - loss: 1.1901e-04 - root_mean_squared_error: 0.0109 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 40/100
# 135/135 [==============================] - 1s 10ms/step - loss: 1.1451e-04 - root_mean_squared_error: 0.0107 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# Epoch 41/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0984e-04 - root_mean_squared_error: 0.0105 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# Epoch 42/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1562e-04 - root_mean_squared_error: 0.0108 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 43/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.1128e-04 - root_mean_squared_error: 0.0105 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 44/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0887e-04 - root_mean_squared_error: 0.0104 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# Epoch 45/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0600e-04 - root_mean_squared_error: 0.0103 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 46/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0579e-04 - root_mean_squared_error: 0.0103 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 47/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0338e-04 - root_mean_squared_error: 0.0102 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 48/100
# 135/135 [==============================] - 1s 9ms/step - loss: 1.0047e-04 - root_mean_squared_error: 0.0100 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 49/100
# 135/135 [==============================] - 2s 13ms/step - loss: 1.0080e-04 - root_mean_squared_error: 0.0100 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# Epoch 50/100
# 135/135 [==============================] - 2s 14ms/step - loss: 9.9233e-05 - root_mean_squared_error: 0.0100 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0324
# Epoch 51/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.7314e-05 - root_mean_squared_error: 0.0099 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 52/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.9435e-05 - root_mean_squared_error: 0.0100 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 53/100
# 135/135 [==============================] - 1s 8ms/step - loss: 9.9015e-05 - root_mean_squared_error: 0.0100 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 54/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.6812e-05 - root_mean_squared_error: 0.0098 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0319
# Epoch 55/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.3354e-05 - root_mean_squared_error: 0.0097 - val_loss: 9.8066e-04 - val_root_mean_squared_error: 0.0313
# Epoch 56/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.6058e-05 - root_mean_squared_error: 0.0098 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0316
# Epoch 57/100
# 135/135 [==============================] - 1s 9ms/step - loss: 9.7251e-05 - root_mean_squared_error: 0.0099 - val_loss: 9.8986e-04 - val_root_mean_squared_error: 0.0315
# Epoch 58/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.8642e-05 - root_mean_squared_error: 0.0094 - val_loss: 9.9963e-04 - val_root_mean_squared_error: 0.0316
# Epoch 59/100
# 135/135 [==============================] - 2s 13ms/step - loss: 8.9307e-05 - root_mean_squared_error: 0.0095 - val_loss: 9.4984e-04 - val_root_mean_squared_error: 0.0308
# Epoch 60/100
# 135/135 [==============================] - 2s 13ms/step - loss: 9.1096e-05 - root_mean_squared_error: 0.0095 - val_loss: 9.7795e-04 - val_root_mean_squared_error: 0.0313
# Epoch 61/100
# 135/135 [==============================] - 1s 10ms/step - loss: 8.8624e-05 - root_mean_squared_error: 0.0094 - val_loss: 9.9891e-04 - val_root_mean_squared_error: 0.0316
# Epoch 62/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.8753e-05 - root_mean_squared_error: 0.0094 - val_loss: 9.5672e-04 - val_root_mean_squared_error: 0.0309
# Epoch 63/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.8560e-05 - root_mean_squared_error: 0.0094 - val_loss: 9.5333e-04 - val_root_mean_squared_error: 0.0309
# Epoch 64/100
# 135/135 [==============================] - 1s 8ms/step - loss: 8.6381e-05 - root_mean_squared_error: 0.0093 - val_loss: 9.5112e-04 - val_root_mean_squared_error: 0.0308
# Epoch 65/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.5429e-05 - root_mean_squared_error: 0.0092 - val_loss: 9.2198e-04 - val_root_mean_squared_error: 0.0304
# Epoch 66/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.6201e-05 - root_mean_squared_error: 0.0093 - val_loss: 8.9587e-04 - val_root_mean_squared_error: 0.0299
# Epoch 67/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.4392e-05 - root_mean_squared_error: 0.0092 - val_loss: 8.9659e-04 - val_root_mean_squared_error: 0.0299
# Epoch 68/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.1756e-05 - root_mean_squared_error: 0.0090 - val_loss: 9.0947e-04 - val_root_mean_squared_error: 0.0302
# Epoch 69/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.0958e-05 - root_mean_squared_error: 0.0090 - val_loss: 8.9579e-04 - val_root_mean_squared_error: 0.0299
# Epoch 70/100
# 135/135 [==============================] - 2s 11ms/step - loss: 9.2986e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.9757e-04 - val_root_mean_squared_error: 0.0300
# Epoch 71/100
# 135/135 [==============================] - 2s 13ms/step - loss: 8.0475e-05 - root_mean_squared_error: 0.0090 - val_loss: 8.7779e-04 - val_root_mean_squared_error: 0.0296
# Epoch 72/100
# 135/135 [==============================] - 1s 10ms/step - loss: 8.0050e-05 - root_mean_squared_error: 0.0089 - val_loss: 8.9648e-04 - val_root_mean_squared_error: 0.0299
# Epoch 73/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.9560e-05 - root_mean_squared_error: 0.0089 - val_loss: 8.6321e-04 - val_root_mean_squared_error: 0.0294
# Epoch 74/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.0931e-05 - root_mean_squared_error: 0.0090 - val_loss: 8.8725e-04 - val_root_mean_squared_error: 0.0298
# Epoch 75/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.9003e-05 - root_mean_squared_error: 0.0089 - val_loss: 8.6814e-04 - val_root_mean_squared_error: 0.0295
# Epoch 76/100
# 135/135 [==============================] - 1s 9ms/step - loss: 8.2528e-05 - root_mean_squared_error: 0.0091 - val_loss: 8.4846e-04 - val_root_mean_squared_error: 0.0291
# Epoch 77/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.9179e-05 - root_mean_squared_error: 0.0089 - val_loss: 8.5370e-04 - val_root_mean_squared_error: 0.0292
# Epoch 78/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.7749e-05 - root_mean_squared_error: 0.0088 - val_loss: 8.4689e-04 - val_root_mean_squared_error: 0.0291
# Epoch 79/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4706e-05 - root_mean_squared_error: 0.0086 - val_loss: 8.4578e-04 - val_root_mean_squared_error: 0.0291
# Epoch 80/100
# 135/135 [==============================] - 2s 11ms/step - loss: 7.5996e-05 - root_mean_squared_error: 0.0087 - val_loss: 8.2935e-04 - val_root_mean_squared_error: 0.0288
# Epoch 81/100
# 135/135 [==============================] - 2s 12ms/step - loss: 7.5962e-05 - root_mean_squared_error: 0.0087 - val_loss: 8.3357e-04 - val_root_mean_squared_error: 0.0289
# Epoch 82/100
# 135/135 [==============================] - 2s 11ms/step - loss: 7.4382e-05 - root_mean_squared_error: 0.0086 - val_loss: 8.4149e-04 - val_root_mean_squared_error: 0.0290
# Epoch 83/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.6007e-05 - root_mean_squared_error: 0.0087 - val_loss: 8.0248e-04 - val_root_mean_squared_error: 0.0283
# Epoch 84/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4842e-05 - root_mean_squared_error: 0.0087 - val_loss: 8.3485e-04 - val_root_mean_squared_error: 0.0289
# Epoch 85/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4810e-05 - root_mean_squared_error: 0.0086 - val_loss: 8.1980e-04 - val_root_mean_squared_error: 0.0286
# Epoch 86/100
# 135/135 [==============================] - 1s 8ms/step - loss: 7.7887e-05 - root_mean_squared_error: 0.0088 - val_loss: 8.0649e-04 - val_root_mean_squared_error: 0.0284
# Epoch 87/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4038e-05 - root_mean_squared_error: 0.0086 - val_loss: 8.2293e-04 - val_root_mean_squared_error: 0.0287
# Epoch 88/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.0574e-05 - root_mean_squared_error: 0.0084 - val_loss: 8.1768e-04 - val_root_mean_squared_error: 0.0286
# Epoch 89/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.3066e-05 - root_mean_squared_error: 0.0085 - val_loss: 7.8376e-04 - val_root_mean_squared_error: 0.0280
# Epoch 90/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4083e-05 - root_mean_squared_error: 0.0086 - val_loss: 8.0426e-04 - val_root_mean_squared_error: 0.0284
# Epoch 91/100
# 135/135 [==============================] - 1s 10ms/step - loss: 7.2165e-05 - root_mean_squared_error: 0.0085 - val_loss: 7.5337e-04 - val_root_mean_squared_error: 0.0274
# Epoch 92/100
# 135/135 [==============================] - 2s 13ms/step - loss: 7.3834e-05 - root_mean_squared_error: 0.0086 - val_loss: 7.7159e-04 - val_root_mean_squared_error: 0.0278
# Epoch 93/100
# 135/135 [==============================] - 1s 10ms/step - loss: 6.9653e-05 - root_mean_squared_error: 0.0083 - val_loss: 7.7632e-04 - val_root_mean_squared_error: 0.0279
# Epoch 94/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.4255e-05 - root_mean_squared_error: 0.0086 - val_loss: 7.8170e-04 - val_root_mean_squared_error: 0.0280
# Epoch 95/100
# 135/135 [==============================] - 1s 9ms/step - loss: 6.8322e-05 - root_mean_squared_error: 0.0083 - val_loss: 7.6015e-04 - val_root_mean_squared_error: 0.0276
# Epoch 96/100
# 135/135 [==============================] - 1s 9ms/step - loss: 6.8549e-05 - root_mean_squared_error: 0.0083 - val_loss: 7.6892e-04 - val_root_mean_squared_error: 0.0277
# Epoch 97/100
# 135/135 [==============================] - 1s 8ms/step - loss: 6.9354e-05 - root_mean_squared_error: 0.0083 - val_loss: 7.9626e-04 - val_root_mean_squared_error: 0.0282
# Epoch 98/100
# 135/135 [==============================] - 1s 8ms/step - loss: 6.9487e-05 - root_mean_squared_error: 0.0083 - val_loss: 7.5751e-04 - val_root_mean_squared_error: 0.0275
# Epoch 99/100
# 135/135 [==============================] - 1s 9ms/step - loss: 7.0928e-05 - root_mean_squared_error: 0.0084 - val_loss: 7.8140e-04 - val_root_mean_squared_error: 0.0280
# Epoch 100/100
# 135/135 [==============================] - 1s 9ms/step - loss: 6.6349e-05 - root_mean_squared_error: 0.0081 - val_loss: 7.5761e-04 - val_root_mean_squared_error: 0.0275

# %%
predictions = model.predict(X_v)
predictions.shape
# Out:
# 180/180 [==============================] - 1s 3ms/step
# (5760, 52)

# %%
path_to_save = '/content/drive/MyDrive/Redes Neurais/results/GRU/multi/sensor_'
try:
    os.remove(path_to_save+".json")
except FileNotFoundError:
    pass

final_result = {}
final_result['Model'] = 'GRU-multi'

for i in range(len(predictions[0])):
  final_result['Sensor'] = i
  final_result['Model'] = 'GRU-multi'
  final_result['MSE_val_final'] = mean_squared_error(y_v[:,i], predictions[:,i]).numpy().tolist()

  with open(path_to_save+".json", "a") as arquivo:
    json.dump(final_result, arquivo)

# %%
plt.plot(history.history['root_mean_squared_error'], label='RME')
plt.plot(history.history['val_root_mean_squared_error'], label = 'val_RME')

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss/RME')
plt.legend(loc='lower right')
plt.savefig(path_to_save+'_loss.png')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
predictions = model.predict(X_v)

predictions.shape
# Out:
# 180/180 [==============================] - 1s 3ms/step
# (5760, 52)

# %%
r = random.randint(0,51)
plt.plot(predictions[:,r])
plt.plot(y_v[:,r])

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_prediction(original_data, predicted_data):
    """
    Plots the original time series, predicted time series, difference between them, and the absolute difference.
    Returns:
        None (displays the plot)
    """

    # Convert data to numpy arrays if they are DataFrames
    if isinstance(original_data, pd.DataFrame):
        original_data = original_data.values
    if isinstance(predicted_data, pd.DataFrame):
        predicted_data = predicted_data.values

    # Compute the difference between the original and predicted data
    diff = original_data - predicted_data
    abs_diff = np.abs(diff)  # Compute the absolute difference

    # Get the number of time series
    num_series = original_data.shape[1]

    # Create subplots for the plots of each time series
    fig, axes = plt.subplots(nrows=num_series, ncols=1, figsize=(10, 5*num_series))
    plt.tight_layout(pad=1.0)

    # Iterate over each time series
    for i in range(num_series):
        ax = axes[i]

        # Plot the original data
        ax.plot(original_data[:, i], label='Original')

        # Plot the predicted data
        ax.plot(predicted_data[:, i], label='Predicted')

        # Plot the difference between original and predicted data
        ax.plot(diff[:, i], label='Difference')

        # Plot the absolute difference
        ax.plot(abs_diff[:, i], label='Absolute Difference')

        # Set the title and legend for each subplot
        ax.set_title(f'Time Series {i+1}')
        ax.legend()
        plt.savefig('/content/drive/MyDrive/Redes Neurais/results/GRU/multi/sensor_'+str(i)+'_diff.png')
        print('.',end='')

    # Display the plot

    plt.show()

# %%
plot_prediction(y_v, predictions)

# %%
from datetime import datetime
import pytz

# Get the current time in Brazil's time zone
brazil_tz = pytz.timezone('America/Sao_Paulo')
current_time = datetime.now(brazil_tz)

# Print the current time
print(current_time)
# Out:
# 2023-06-25 17:24:29.918055-03:00
